# %%
! pip install pytelegrambotapi

# %%
import telebot

# %%
API_TOKEN = '6415234306:AAH3BIYJODrZAWFO4NN25g1uUyMYo0TJg7g'
bot = telebot.TeleBot(API_TOKEN)

# %%
# !pip install pandas pandasai

# %%
import pandas as pd
from pandasai import SmartDataframe

# %%
from pandasai.llm import OpenAI
llm = OpenAI(api_token="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")

# %%
df = pd.read_csv("https://raw.githubusercontent.com/brunodenardo/ImdbTelegramBot/main/IMDB%20Top%20250%20Movies.csv")

# %%
df = SmartDataframe(df, config={"llm": llm})

# %%
df.chat('Show me ten movies')["movies"].to_string(index=False)

# %%
@bot.message_handler(func=lambda message: True)
def response(message):

  response = df.chat(message.text)["movies"].to_string(index=False)


  bot.reply_to(message, response)

# %%
bot.polling()
